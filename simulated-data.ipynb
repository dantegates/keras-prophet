# %% [markdown]
# # Regression

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

n_items = 100
n_dates = 900
periods = [
    (7, 3),
    (365.25, 20),
]


def generate_seasonalities(t, n, period, order):
    t = np.arange(t)[None, :]
    N = np.arange(order)[:, None]
    a_n = np.random.normal(size=(n, order))
    b_n = np.random.normal(size=(n, order))
    return (
        a_n.dot(np.sin((2 * np.pi * (N * t)) / period))
        + b_n.dot(np.cos((2 * np.pi * (N * t)) / period))
    )


trends = (
    # intercept
    np.random.normal(size=(n_items, 1))
    + np.cumsum(
        # changepoints
        np.random.normal(size=(n_items, n_dates))
        # mask
        * np.random.choice([0, 1], size=(n_items, n_dates), p=[.98, .02]),
        axis=1)
)
trends *= (np.arange(n_dates)[None, :] / 100)
seasonalities = [
    m * generate_seasonalities(n_dates, n_items, P, order)
    for m, (P, order) in zip((5, 25), periods)
]

y = trends + np.sum(seasonalities, axis=0)

fig, axs = plt.subplots(2 + len(seasonalities), figsize=(10, 10))

axs[0].plot(y.T, color='C0', alpha=.4)
_ = axs[1].plot(trends.T, color='C0', alpha=.4)
for ax, s, (P, _) in zip(axs[2:], seasonalities, periods):
    ax.plot(s[:, :round(P)].T, color='C0', alpha=.4)
    
for ax, title in zip(axs, ['Target', 'Trend', *[f'{day} Day Seasonality' for day in periods]]):
    ax.set_title(title)
    
plt.subplots_adjust(top=1.4)

# %%
if False:
    # %run stl.py
    model = STL(
        n_items=n_items,
        embedding_dim=None,
        n_inner_layers=None,
        n_outer_layers=2,
        t0=None,
        t_range=(0, n_dates),
        trends=[(1, 20, .8)],
        periods=[(7, 3), (365.25, 10)],
        output_activations=['linear']
    )
    model._model.compile(loss='mse', optimizer='adam')
else:
    # %run ryan_adams.py
    model = RyanAdadms(
        trends=LinearTrend(
            n_items=n_items,
            t_range=(0, n_dates)
        ),
        seasonalities=[
            Seasonality(n_items=n_items, period=7, order=3),
            Seasonality(n_items=n_items, period=365.25, order=10),
        ],
        outer_layers=[
            keras.layers.Dense(3, activation='linear'),
            keras.layers.Dense(3, activation='linear'),
        ]
    )
# Out:
# 2022-07-31 21:00:47.107543: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X = pd.DataFrame({
    'id': np.repeat(np.arange(n_items), n_dates),
    't': np.tile(np.arange(n_dates), n_items),
    'y': y.ravel()
})

Xt = X[['id', 't']].to_dict('series')
model._model.fit(
    Xt, X.y,
    batch_size=1024,
    epochs=50
)
# Out:
# Epoch 1/50
# 88/88 [==============================] - 2s 3ms/step - loss: 12271.6191
# Epoch 2/50
# 88/88 [==============================] - 0s 3ms/step - loss: 12012.6504
# Epoch 3/50
# 88/88 [==============================] - 0s 3ms/step - loss: 11946.5645
# Epoch 4/50
# 88/88 [==============================] - 0s 3ms/step - loss: 11851.1963
# Epoch 5/50
# 88/88 [==============================] - 0s 3ms/step - loss: 11689.5918
# Epoch 6/50
# 88/88 [==============================] - 0s 3ms/step - loss: 11407.1484
# Epoch 7/50
# 88/88 [==============================] - 0s 3ms/step - loss: 10915.8574
# Epoch 8/50
# 88/88 [==============================] - 0s 3ms/step - loss: 10102.3467
# Epoch 9/50
# 88/88 [==============================] - 0s 3ms/step - loss: 8935.2266
# Epoch 10/50
# 88/88 [==============================] - 0s 3ms/step - loss: 7616.4785
# Epoch 11/50
# 88/88 [==============================] - 0s 3ms/step - loss: 6547.4189
# Epoch 12/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5968.0249
# Epoch 13/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5747.3447
# Epoch 14/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5668.3604
# Epoch 15/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5626.3799
# Epoch 16/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5599.9092
# Epoch 17/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5574.4692
# Epoch 18/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5559.4131
# Epoch 19/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5543.2812
# Epoch 20/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5536.0596
# Epoch 21/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5526.8691
# Epoch 22/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5518.9424
# Epoch 23/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5514.3384
# Epoch 24/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5507.7578
# Epoch 25/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5501.8203
# Epoch 26/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5498.1572
# Epoch 27/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5494.3340
# Epoch 28/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5491.0928
# Epoch 29/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5489.2271
# Epoch 30/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5485.0068
# Epoch 31/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5486.6060
# Epoch 32/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5482.7036
# Epoch 33/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5483.9541
# Epoch 34/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5480.9448
# Epoch 35/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5479.4565
# Epoch 36/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5479.7056
# Epoch 37/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5474.3984
# Epoch 38/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5476.6050
# Epoch 39/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5471.8242
# Epoch 40/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5474.7441
# Epoch 41/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5472.9561
# Epoch 42/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5471.2192
# Epoch 43/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5470.2861
# Epoch 44/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5468.3208
# Epoch 45/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5471.3418
# Epoch 46/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5465.9375
# Epoch 47/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5470.2163
# Epoch 48/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5463.9521
# Epoch 49/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5465.2080
# Epoch 50/50
# 88/88 [==============================] - 0s 3ms/step - loss: 5467.5854

# %%
model._model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  t (InputLayer)                 [(None, 1)]          0           []
#
#  id (InputLayer)                [(None, 1)]          0           []
#
#  linear_trend (LinearTrend)     (None, 1)            2200        ['t[0][0]',
#                                                                   'id[0][0]']
#
#  seasonality (Seasonality)      (None, 1)            600         ['t[0][0]',
#                                                                   'id[0][0]']
#
#  seasonality_1 (Seasonality)    (None, 1)            2000        ['t[0][0]',
#                                                                   'id[0][0]']
#
#  concatenate (Concatenate)      (None, 3)            0           ['linear_trend[0][0]',
#                                                                   'seasonality[0][0]',
#                                                                   'seasonality_1[0][0]']
#
#  dense (Dense)                  (None, 3)            12          ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 3)            12          ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 1)            4           ['dense_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 1)            0           ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 4,828
# Trainable params: 4,828
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X['p'] = model._model.predict(Xt)

# %%
(X.y - X.p).hist()
# Out:
# <AxesSubplot:>

# %%
i = np.random.randint(n_items)
X.set_index('id').loc[i].set_index('t')[['y', 'p']].plot()
# Out:
# <AxesSubplot:xlabel='t'>

# %% [markdown]
# # Logistic Growth

# %%
import matplotlib.pyplot as plt
import numpy as np


saturation_point = 1e6
n_items = 1
n_dates = 900
periods = [
    (7, 3),
    (365.25, 20),
]


def generate_seasonalities(t, n, period, order):
    t = np.arange(t)[None, :]
    N = np.arange(order)[:, None]
    a_n = np.random.normal(size=(n, order))
    b_n = np.random.normal(size=(n, order))
    return (
        a_n.dot(np.sin((2 * np.pi * (N * t)) / period))
        + b_n.dot(np.cos((2 * np.pi * (N * t)) / period))
    )


trends = (
    # intercept
    np.random.normal(size=(n_items, 1))
    + np.cumsum(
        # changepoints
        np.abs(np.random.normal(0, .5, size=(n_items, n_dates)))
        # mask
        * np.random.choice([0, 1], size=(n_items, n_dates), p=[.98, .02]),
        axis=1)
)
trends = (saturation_point / ( 1 + np.exp(-trends * (np.arange(n_dates)[None, :] / 100))))
seasonalities = [
    m * generate_seasonalities(n_dates, n_items, P, order)
    for m, (P, order) in zip((saturation_point / 10, saturation_point / 100), periods)
]

y = trends + np.sum(seasonalities, axis=0)
y = (y - y.mean()) / y.std()

fig, axs = plt.subplots(2 + len(seasonalities), figsize=(10, 10))

axs[0].plot(y.T, color='C0', alpha=.4)
_ = axs[1].plot(trends.T, color='C0', alpha=.4)
for ax, s, (P, _) in zip(axs[2:], seasonalities, periods):
    ax.plot(s[:, :round(P)].T, color='C0', alpha=.4)

for ax, title in zip(axs, ['Target', 'Trend', *[f'{day} Day Seasonality' for day in periods]]):
    ax.set_title(title)
    
plt.subplots_adjust(top=1.4)

# %%
if False:
    # %run stl.py
    model = STL(
        n_items=n_items,
        embedding_dim=None,
        n_inner_layers=None,
        n_outer_layers=2,
        t0=None,
        t_range=(0, n_dates),
        trends=[(1, 20, .8)],
        periods=[(7, 3), (365.25, 10)],
        output_activations=['linear']
    )
    model._model.compile(loss='mse', optimizer='adam')
else:
    # %run ryan_adams.py
    model = RyanAdadms(
        trends=LinearTrend(
            n_items=n_items,
            t_range=(0, n_dates),
        ),
        seasonalities=[
            Seasonality(n_items=n_items, period=7, order=3),
            Seasonality(n_items=n_items, period=365.25, order=10),
        ],
        outer_layers=[
            keras.layers.Dense(3, activation='linear'),
            keras.layers.Dense(3, activation='linear'),
        ]
    )

# %%
X = pd.DataFrame({
    'id': np.repeat(np.arange(n_items), n_dates),
    't': np.tile(np.arange(n_dates), n_items),
    'y': y.ravel()
})

Xt = X[['id', 't']].to_dict('series')
model._model.fit(
    Xt, X.y,
    batch_size=32,
    epochs=50,
)
# Out:
# Epoch 1/50
# /Users/dantegates/virtualenvs/v3.8/lib/python3.8/site-packages/keras/engine/functional.py:559: UserWarning: Input dict contained keys ['id'] which did not match any model input. They will be ignored by the model.
#   inputs = self._flatten_to_reference_inputs(inputs)
# 29/29 [==============================] - 2s 2ms/step - loss: 397.9424
# Epoch 2/50
# 29/29 [==============================] - 0s 2ms/step - loss: 17.5627
# Epoch 3/50
# 29/29 [==============================] - 0s 2ms/step - loss: 3.5441
# Epoch 4/50
# 29/29 [==============================] - 0s 2ms/step - loss: 2.8001
# Epoch 5/50
# 29/29 [==============================] - 0s 2ms/step - loss: 2.4996
# Epoch 6/50
# 29/29 [==============================] - 0s 3ms/step - loss: 2.3176
# Epoch 7/50
# 29/29 [==============================] - 0s 2ms/step - loss: 2.1481
# Epoch 8/50
# 29/29 [==============================] - 0s 2ms/step - loss: 2.0032
# Epoch 9/50
# 29/29 [==============================] - 0s 2ms/step - loss: 1.8608
# Epoch 10/50
# 29/29 [==============================] - 0s 2ms/step - loss: 1.7338
# Epoch 11/50
# 29/29 [==============================] - 0s 2ms/step - loss: 1.6131
# Epoch 12/50
# 29/29 [==============================] - 0s 2ms/step - loss: 1.5054
# Epoch 13/50
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4044
# Epoch 14/50
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3170
# Epoch 15/50
# 29/29 [==============================] - 0s 2ms/step - loss: 1.2256
# Epoch 16/50
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1507
# Epoch 17/50
# 29/29 [==============================] - 0s 3ms/step - loss: 1.0817
# Epoch 18/50
# 29/29 [==============================] - 0s 3ms/step - loss: 1.0109
# Epoch 19/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.9544
# Epoch 20/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.8981
# Epoch 21/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.8454
# Epoch 22/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.7970
# Epoch 23/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.7403
# Epoch 24/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6955
# Epoch 25/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6553
# Epoch 26/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6104
# Epoch 27/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5788
# Epoch 28/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5421
# Epoch 29/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5092
# Epoch 30/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4818
# Epoch 31/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4580
# Epoch 32/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4353
# Epoch 33/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4107
# Epoch 34/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3914
# Epoch 35/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3747
# Epoch 36/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3593
# Epoch 37/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3445
# Epoch 38/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3289
# Epoch 39/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3170
# Epoch 40/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3066
# Epoch 41/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2949
# Epoch 42/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2855
# Epoch 43/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2759
# Epoch 44/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2683
# Epoch 45/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2605
# Epoch 46/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2587
# Epoch 47/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2494
# Epoch 48/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2414
# Epoch 49/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2353
# Epoch 50/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2300

# %%
X['p'] = model._model.predict(Xt)

# %%
(X.y - X.p).hist()
# Out:
# <AxesSubplot:>

# %%
i = np.random.randint(n_items)
X.set_index('id').loc[i].set_index('t')[['y', 'p']].plot()
# Out:
# <AxesSubplot:xlabel='t'>

# %% [markdown]
# # Conversion Rates

# %%
import scipy.stats as ss
import scipy.special as spc


t = np.arange(365 * 5)


def periodic_rbf(x, p, a, m, c):
    return c * np.exp(-.5 * a * ((x % p) - m) ** 2)


product_release = 1 + (t > 500) * .7
table_dropped = 1 - ((t > 1050) & (t < 1100)) * .9

growth = 10 * np.log((t + 90) / 100) * product_release * table_dropped
noise = np.random.normal(size=len(t))

modifier_ix = (t // 365.25).astype(int)
modifier = np.random.normal(size=modifier_ix.max() + 1)
yearly_effect1 = periodic_rbf(t, 365.25, .01, 30, 10) - periodic_rbf(t, 365.25, .001, 33, 15)
yearly_effect1 *= abs(modifier[modifier_ix])

yearly_effect2 = periodic_rbf(t, 365.25, .001, 210, 20) / np.log10(t + 10)

weekly_effect = periodic_rbf(t, 7, 1, 5, 5)


y = growth + yearly_effect1 + yearly_effect2 + weekly_effect + noise
y = .03 * (y - y.min()) / (y.max() - y.min()) + .015

plt.plot(y)

# %%
import scipy.stats as ss


time_to_convert = ss.weibull_min(c=1.2, scale=40)

y_observed = y * time_to_convert.cdf(t.max() - t)

plt.plot(y)
plt.plot(y_observed, ls='--')

# %%
# %run stl.py

import tensorflow as tf
from tensorflow_probability import distributions as tfd

def conversion_rate_loss(y_observed, y_θ):
    c, n, t = y_observed[:, 0], y_observed[:, 1], y_observed[:, 2]
    p, k, λ, p_outlier = y_θ[:, 0], y_θ[:, 1], y_θ[:, 2], y_θ[:, 3]
    k = tf.math.sqrt(k)
    k = 1.2
    λ = 40#tf.math.sqrt(λ)
    p_star = p * tfd.Weibull(k, λ).cdf(t)
    return -(
        p_outlier * tf.math.log(.01)
        + (1 - p_outlier) * tfd.Binomial(total_count=n, probs=p_star).log_prob(c)
    )


t_range = t.min(), t.max()

s = lambda x: tf.math.softplus(x)
model_p = STL(
    n_items=1,
    embedding_dim=None,
    n_inner_layers=1,
    n_outer_layers=1,
    t0=None,
    t_range=t_range,
    # trends=[('linear', 1, 25, .8)],
    periods=[(7, 3), (365.25, 10)],
    n_ensemble=1,
    output_activations=['sigmoid']
)

model_k = STL(
    n_items=1,
    embedding_dim=None,
    n_inner_layers=1,
    n_outer_layers=1,
    t0=None,
    t_range=t_range,
    # trends=[('linear', 2, 1, 25, .8)],
    periods=[(7, 3), (365.25, 10)],
    n_ensemble=1,
    output_activations=['softplus'],
    inputs=model_p._model.inputs
)


model_θ = STL(
    n_items=1,
    embedding_dim=None,
    n_inner_layers=1,
    n_outer_layers=1,
    t0=None,
    t_range=t_range,
    # trends=[('linear', 1, 1, 25, .8)],
    periods=[(7, 3), (365.25, 10)],
    n_ensemble=1,
    output_activations=['softplus'],
    inputs=model_p._model.inputs
)

model_outlier = STL(
    n_items=1,
    embedding_dim=None,
    n_inner_layers=1,
    n_outer_layers=1,
    t0=None,
    t_range=t_range,
    # trends=[('linear', 1, 1, 25, .8)],
    periods=[(7, 3), (365.25, 10)],
    n_ensemble=1,
    output_activations=['sigmoid'],
    inputs=model_p._model.inputs
)


inputs = model_p.inputs
outputs = tf.keras.layers.Concatenate()(
    model_p._model.outputs
    + model_k._model.outputs
    + model_θ._model.outputs
    + model_outlier._model.outputs
)

model = tf.keras.models.Model(
    inputs=inputs,
    outputs=outputs
)

model.compile(loss=conversion_rate_loss, optimizer='adam')

# %%
# model.summary()

# %%
Xt = {'t': t.astype('float') + 1, 'id': np.zeros_like(t)}
yt = np.vstack([
    y_observed * 1e8,
    np.ones_like(t) * 1e8,
    t.max() + 1 - t
]).astype('float32').T

plt.plot(model.predict(Xt)[:, [1, 2]])#, label=['p', 'k', 'θ', 'outlier'])
plt.gca().legend()

# %%
initial_predictions = model.predict(Xt)
initial_loss = conversion_rate_loss(yt, initial_predictions)
assert not np.isnan(initial_loss.numpy()).any(), np.isnan(initial_loss.numpy()).mean()

# %%
# p, λ, k, p_outlier
initial_predictions.min(axis=0), initial_predictions.max(axis=0)

# %%
# model._model.summary()

# %%
model.fit(
    Xt, yt,
    batch_size=2000,
    epochs=20,
)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(y, label='True Conversion Rates')
ax.plot(model.predict(Xt)[:, 0], label='Predicted Conversion Rates')
ax.plot(y_observed, color='C7', label='ObservedConversion Rates', alpha=.5)

ax.legend()

# %%
model_p._trend_layers[-1].s

# %%
model._

# %%
model.plot()
